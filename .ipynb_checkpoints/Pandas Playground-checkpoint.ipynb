# %% [markdown]
# <h1 style="color:blue;text-align:center;font-size:3em">Pandas Playground</h1>

# %%
import pandas as pd

# %% [markdown]
# <h2>Read CSV</h2>

# %%
# In gerenal, this is the methody you will use the most to create dataframes. 
# CSV is the standard format for providing tabular data.
df = pd.read_csv('telco_churn.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# <h1>Create</h1>

# %% [markdown]
# <h2>Create from a Dictionary</h2>

# %%
# The important thing to note here is that you need to access the DataFrame type to create a dataframe from a dictionary.
tempDict = { 'col1': [1, 2, 3], 'col2': [4, 5, 6], 'col3': [7, 8, 9] }
dictdf = pd.DataFrame.from_dict(tempDict)
dictdf
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
# Previews the first x rows of your dataframe. 
# The parameter will allow you to specify the number of rows; five is default.
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
# Previews the last x rows of your dataframe; five is default.
df.tail(3)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3330             30.74              288.8             58.0             24.55
# 3331             36.35              159.6             84.0             13.57
# 3332             39.85              265.9             82.0             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# ...

# %% [markdown]
# <h2>Columns and Data Types</h2>

# %%
# This will give you a list of all of the features.
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# This will give you a list of all the features and the types; The list is nicer to read.
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %% [markdown]
# <h2>Summary Statistics</h2>

# %%
# This handy method will give you a statistical summary of the data.
# This method will only perform calculations on numerical values
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
# This will perform calculations on categorical objects.
df.describe(include='object')
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3325
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2842

# %% [markdown]
# <h1>Read</h1>

# %% [markdown]
# <h2>Filtering Columns</h2>

# %%
# You could filter by using `df.State`, however, this method will only work on single word features.
df['State']
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
# You can filter multiple features at the same time.
df[['State', 'International plan']]
# Out:
#      State International plan
# 0       KS                 No
# 1       OH                 No
# 2       NJ                 No
# 3       OH                Yes
# 4       OK                Yes
# ...    ...                ...
# 3328    AZ                 No
# 3329    WV                 No
# 3330    RI                 No
# 3331    CT                Yes
# 3332    TN                 No
#
# [3333 rows x 2 columns]

# %%
# This will give you a list of unique values.
df['Area code'].unique()
# Out:
# array([415, 408, 510])

# %% [markdown]
# <h2>Filtering Rows</h2>

# %%
# You can create a list based on a condition.
df['International plan']=='No'
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 3328     True
# 3329     True
# 3330     True
# 3331    False
# 3332     True
# Name: International plan, Length: 3333, dtype: bool

# %%
# Printing the entire dataframe with values that meet the condition.
df[df['International plan']=='No']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# Multiple conditions; Notice the parenthesis.
df[(df['International plan']=='No') & (df['Churn']==False)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 8       LA             117        408                 No              No
# 11      RI              74        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# <h2>iLoc</h2>

# %%
df.iloc[12]
# Out:
# State                        IA
# Account length              168
# Area code                   408
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         104.9
# Total eve calls            71.0
# Total eve charge           8.92
# Total night minutes       141.1
# Total night calls         128.0
# Total night charge         6.35
# Total intl minutes         11.2
# Total intl calls              2
# Total intl charge          3.02
# Customer service calls      1.0
# Churn                     False
# Name: 12, dtype: object

# %%
# First parameter is the row, second is the column; iloc is zero indexed.
df.iloc[12, 2]
# Out:
# 408

# %%
# You can get a range of values.
df.iloc[22:33, :3]
# Out:
#    State  Account length  Area code
# 22    AZ             130        415
# 23    SC             111        415
# 24    VA             132        510
# 25    NE             174        415
# 26    WY              57        408
# 27    MT              54        408
# 28    MO              20        415
# 29    HI              49        510
# 30    IL             142        415
# 31    NH              75        510
# 32    LA             172        408

# %%
# This is a common pattern you will see.
# The dependent variable is tranditionally the last column. This will extract all of the rows of the dependent columns
# The first parameter is all rows
# The second parameter is up to the excluding the last column (independent variable).
df.iloc[:, :-1]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# <h2>loc</h2>

# %%
# When we copy in a csv, the index is automatically created as integer values.
# When using loc, we need something else to be the index.
state = df.copy()
state.set_index('State', inplace=True)
state

# %%
# We are using the loc method to get all of the rows that are OH. 
# We could do this with a conditional, however, this might be slightly cleaner.
state.loc['OH']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                107        415                 No             Yes
# OH                 84        408                Yes              No
# OH                 65        408                 No              No
# OH                 83        415                 No              No
# OH                 63        415                Yes             Yes
# ...               ...        ...                ...             ...
# OH                160        415                 No              No
# OH                 88        408                 No              No
# OH                106        415                 No             Yes
# OH                 78        408                 No              No
# OH                 96        415                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        26              161.6            123.0
# ...

# %% [markdown]
# <h1>Update</h1>

# %%
# This will give you information on how many values are null in each feature.
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
# This will drop all of the rows that have a null value
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
# We can drop a column. You can add an inplace parameter to update the df object.
df.drop('Area code', axis=1)
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# ...

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...
